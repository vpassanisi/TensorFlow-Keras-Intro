# %%
import tensorflow as tf


mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

model.fit(x_train, y_train, epochs=3)
# Out:
# Epoch 1/3
# 1875/1875 [==============================] - 1s 771us/step - loss: 0.2628 - accuracy: 0.9240
# Epoch 2/3
# 1875/1875 [==============================] - 1s 708us/step - loss: 0.1075 - accuracy: 0.9672
# Epoch 3/3
# 1875/1875 [==============================] - 1s 678us/step - loss: 0.0738 - accuracy: 0.9765

# %%
val_loss, val_acc = model.evaluate(x_test, y_test)
print(val_loss, val_acc)
# Out:
# 313/313 [==============================] - 0s 484us/step - loss: 0.1046 - accuracy: 0.9669
# 0.1045832633972168 0.9668999910354614

# %%
import matplotlib.pyplot as plt

plt.imshow(x_train[1], cmap=plt.cm.binary)

# %%
model.save('num_reader')
# Out:
# INFO:tensorflow:Assets written to: num_reader\assets

# %%
new_model = tf.keras.models.load_model('num_reader/')

# %%
predictions = new_model.predict(x_test)
print(predictions)
# Out:
# [[4.80247984e-08 2.93948726e-10 5.10252278e-07 ... 9.99998927e-01
#   1.14805065e-09 9.61284528e-08]
#  [1.80664756e-07 2.67578376e-04 9.99731123e-01 ... 1.39659821e-08
#   9.49003223e-08 1.71880454e-09]
#  [1.01433886e-06 9.99486804e-01 4.27993800e-05 ... 2.38527820e-04
#   5.64657239e-05 4.11459077e-05]
#  ...
#  [1.17460459e-07 8.51385664e-07 9.22211854e-08 ... 1.71114025e-05
#   2.35285052e-06 2.99994019e-03]
#  [1.43585676e-05 2.79888496e-07 1.43115460e-06 ... 2.54037004e-05
#   4.97284753e-04 1.82253061e-07]
#  [3.73991966e-08 4.15475903e-08 2.49949110e-08 ... 2.00611628e-11
#   1.03843966e-07 1.77101811e-09]]

# %%
import numpy as np

print(np.argmax(predictions[3]))

plt.imshow(x_test[3])
plt.show()
# Out:
# 0
